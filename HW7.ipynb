# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account- BBC
target_user = "@BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Twitter Handle": target_user,
                           "Text": tweet["text"]})
        
        # Add to counter 
        counter += 1

# %%
# Target Account- CBS News
target_user2 = "@CBSNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments2 = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user2, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments2.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Twitter Handle": target_user2,
                           "Text": tweet["text"]})
        
        # Add to counter 
        counter += 1

# %%
# Target Account- CNN 
target_user3 = "@CNN"

# Counter
counter = 1

# Variables for holding sentiments
sentiments3 = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user3, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments3.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Twitter Handle": target_user3,
                           "Text": tweet["text"]})
        
        # Add to counter 
        counter += 1

# %%
# Target Account- Fox News
target_user4 = "@FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments4 = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user4, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments4.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Twitter Handle": target_user4,
                           "Text": tweet["text"]})
        
        # Add to counter 
        counter += 1

# %%
# Target Account- New York Times
target_user5 = "@nytimes"

# Counter
counter = 1

# Variables for holding sentiments
sentiments5 = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user5, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments5.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Twitter Handle": target_user5,
                           "Text": tweet["text"]})
        
        # Add to counter 
        counter += 1

# %%
# Convert sentiments to DataFrame for BBC
sentiments_bbc = pd.DataFrame.from_dict(sentiments)
sentiments_bbc.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sun Apr 08 19:02:05 +0000 2018     1.000    0.000     0.000
# 1    0.4939  Sun Apr 08 18:03:03 +0000 2018     0.686    0.000     0.314
# 2    0.2500  Sun Apr 08 17:25:08 +0000 2018     0.765    0.088     0.147
# 3    0.0000  Sun Apr 08 17:07:02 +0000 2018     1.000    0.000     0.000
# 4    0.0000  Sun Apr 08 16:40:55 +0000 2018     1.000    0.000     0.000
#
#                                                 Text  Tweets Ago  \
# 0  😺💦 This is Maya the jaguar's very first swim! ...           1
# 1  😂 Need a hand getting the kids to bed? https:/...           2
# 2  'Silencing masks' and 'wife auctions': What li...           3
# 3  🦖😂 Philomena Cunk examines the barbaric condit...           4
# 4  RT @bbcgetinspired: Meet Sue...\n\nShe is plan...           5
#
#   Twitter Handle
# 0           @BBC
# 1           @BBC
# 2           @BBC
# 3           @BBC
# 4           @BBC

# %%
#export the data in the DataFrame into a CSV File
sentiments_bbc.to_csv("BBC")

# %%
# Convert sentiments to DataFrame for CBS News
sentiments_cbsnews = pd.DataFrame.from_dict(sentiments2)
sentiments_cbsnews.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sun Apr 08 20:25:01 +0000 2018     1.000    0.000     0.000
# 1    0.3182  Sun Apr 08 20:08:02 +0000 2018     0.585    0.140     0.275
# 2   -0.8360  Sun Apr 08 19:45:01 +0000 2018     0.473    0.527     0.000
# 3    0.0000  Sun Apr 08 19:25:02 +0000 2018     1.000    0.000     0.000
# 4    0.2023  Sun Apr 08 19:05:01 +0000 2018     0.870    0.000     0.130
#
#                                                 Text  Tweets Ago  \
# 0  Bernie Taupin, Elton John's musical collaborat...           1
# 1  Jimmy Kimmel apologizes for gay joke amid feud...           2
# 2  Man arrested for Indianapolis knife attack tha...           3
# 3  Tina Fey is now bringing "Mean Girls" -- her 2...           4
# 4  Antonio Banderas on playing Pablo Picasso in t...           5
#
#   Twitter Handle
# 0       @CBSNews
# 1       @CBSNews
# 2       @CBSNews
# 3       @CBSNews
# 4       @CBSNews

# %%
#export the data in the DataFrame into a CSV File
sentiments_cbsnews.to_csv("CBS News")

# %%
# Convert sentiments to DataFrame for CNN
sentiments_cnn = pd.DataFrame.from_dict(sentiments3)
sentiments_cnn.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sun Apr 08 20:15:04 +0000 2018     1.000    0.000     0.000
# 1    0.0000  Sun Apr 08 20:00:18 +0000 2018     1.000    0.000     0.000
# 2    0.7108  Sun Apr 08 19:45:18 +0000 2018     0.763    0.000     0.237
# 3    0.0000  Sun Apr 08 19:30:06 +0000 2018     1.000    0.000     0.000
# 4   -0.8834  Sun Apr 08 19:15:07 +0000 2018     0.558    0.442     0.000
#
#                                                 Text  Tweets Ago  \
# 0  Polls open as Hungary's Euroskeptic leader Orb...           1
# 1  "Saturday Night Live" returns to take shots at...           2
# 2  It's the great what if in political history. W...           3
# 3  Cambridge Analytica whistleblower says data co...           4
# 4  Hockey community grieves after 15 killed in bu...           5
#
#   Twitter Handle
# 0           @CNN
# 1           @CNN
# 2           @CNN
# 3           @CNN
# 4           @CNN

# %%
#export the data in the DataFrame into a CSV File
sentiments_cnn.to_csv("CNN")

# %%
# Convert sentiments to DataFrame for Fox News
sentiments_foxnews = pd.DataFrame.from_dict(sentiments4)
sentiments_foxnews.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sun Apr 08 20:16:21 +0000 2018     1.000    0.000     0.000
# 1   -0.7964  Sun Apr 08 20:14:41 +0000 2018     0.664    0.336     0.000
# 2    0.0000  Sun Apr 08 20:10:25 +0000 2018     1.000    0.000     0.000
# 3    0.5267  Sun Apr 08 20:03:00 +0000 2018     0.841    0.000     0.159
# 4   -0.6486  Sun Apr 08 20:01:02 +0000 2018     0.694    0.306     0.000
#
#                                                 Text  Tweets Ago  \
# 0  States sending troops to Mexico border. https:...           1
# 1  Amb. Dan Gillerman on Syria suspected chemical...           2
# 2  Trump slams Obama over not crossing 'red line'...           3
# 3  TONIGHT on "Life, Liberty, &amp; Levin," @Sara...           4
# 4  Outrage at Kimmel comments on Melania surges a...           5
#
#   Twitter Handle
# 0       @FoxNews
# 1       @FoxNews
# 2       @FoxNews
# 3       @FoxNews
# 4       @FoxNews

# %%
#export the data in the DataFrame into a CSV File
sentiments_foxnews.to_csv("Fox News")

# %%
# Convert sentiments to DataFrame for New York Times
sentiments_nyt = pd.DataFrame.from_dict(sentiments5)
sentiments_nyt.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.2732  Sun Apr 08 20:11:02 +0000 2018     0.826    0.000     0.174
# 1    0.5256  Sun Apr 08 19:56:07 +0000 2018     0.825    0.000     0.175
# 2    0.0000  Sun Apr 08 19:41:05 +0000 2018     1.000    0.000     0.000
# 3    0.4069  Sun Apr 08 19:26:01 +0000 2018     0.732    0.121     0.146
# 4   -0.2023  Sun Apr 08 19:11:32 +0000 2018     0.808    0.112     0.081
#
#                                                 Text  Tweets Ago  \
# 0  Here's how to start a fitness routine – and st...           1
# 1  "Facebook has got to start treating influencer...           2
# 2  Charlie Brown, Snoopy and the rest of the Pean...           3
# 3  "I will do my best to see to it that I never a...           4
# 4  RT @cdcaron: It has been nearly five years sin...           5
#
#   Twitter Handle
# 0       @nytimes
# 1       @nytimes
# 2       @nytimes
# 3       @nytimes
# 4       @nytimes

# %%
#export the data in the DataFrame into a CSV File
sentiments_nyt.to_csv("NYT")

# %%
# Create plots
def plotting_scatter(x, y, color, label):
    return plt.scatter(x, y, c = color, alpha = 0.5, s = 200, label = label)

# %%
#Create scatter plot
plt.figure(figsize =(10,10))

plotting_scatter(sentiments_bbc['Tweets Ago'], sentiments_bbc['Compound'], "b", 'BBC')
plotting_scatter(sentiments_cbsnews['Tweets Ago'], sentiments_cbsnews['Compound'], "g", 'CBS')
plotting_scatter(sentiments_cnn['Tweets Ago'], sentiments_cnn['Compound'], "r", 'CNN')
plotting_scatter(sentiments_foxnews['Tweets Ago'], sentiments_foxnews['Compound'], "c", 'Fox')
plotting_scatter(sentiments_nyt['Tweets Ago'], sentiments_nyt['Compound'], "m", 'NYT')

plt.legend(loc = "best")
plt.title("Sentiment Analysis of Media Tweets 4/8/2018")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweets Polarity")
plt.xlim(105, -0.04)
plt.show()

# %%
#save scatterplot
plt.savefig("Sentiment Analysis of Media Tweets")

# %%
#Create bar plot

#find means for each compound
average_compound = {
    "BBC" : np.mean(sentiments_bbc['Compound']),
    "CBS" : np.mean(sentiments_cbsnews['Compound']),
    "CNN" : np.mean(sentiments_cnn['Compound']),
    "FOX" : np.mean(sentiments_cbsnews['Compound']),
    "NYT" : np.mean(sentiments_foxnews['Compound'])
}
average_compound
# Out:
# {'BBC': 0.091746,
#  'CBS': -0.22752899999999998,
#  'CNN': -0.104058,
#  'FOX': -0.22752899999999998,
#  'NYT': -0.10743900000000002}

# %%
#put together the bar plot
plt.figure(figsize = (8,8))
plt.bar(average_compound.keys(), average_compound.values(), color = ['b', 'g', 'r', 'c', 'm'])
plt.title('Overall Media Sentiment Based on Twitter (4/8/2018)')
plt.ylabel("Tweet Polarity")
plt.ylim(-0.3, 0.3)
plt.show()

# %%
#save bar plot
plt.savefig("Overall Media Sentiment Based on Twitter")
